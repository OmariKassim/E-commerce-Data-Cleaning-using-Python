# %%
import pandas as pd
import numpy as np
import seaborn as sns
import plotly as py

# %%
Data = pd.read_csv(r"C:\Users\omarm\Documents\Career Essentials & Job Apps\Guided Projects with Business Problems-or-Requirements\Amazon_ecommerce_sample.csv")
Data
# Out:
#                                uniq_id  \
# 0     eac7efa5dbd3d667f26eb3d3ab504464
# 1     b17540ef7e86e461d37f3ae58b7b72ac
# 2     348f344247b0c1a935b1223072ef9d8a
# 3     e12b92dbb8eaee78b22965d2a9bbbd9f
# 4     e33a9adeed5f36840ccc227db4682a36
# ...                                ...
# 9995  44d6967f083825a5de36ad4865a65bcd
# 9996  08f0747b6fc6687215ffb994c3a6fb32
# 9997  bf6cc073f8f24e6e338190fa16f6ee9d
# 9998  cd783d0b8b44e631b9788b203eaaefae
# 9999  94d18e86e504bee1e392df7e5738b18a
#
#                                            product_name  \
# 0                                 Hornby 2014 Catalogue
# 1     FunkyBuys® Large Christmas Holiday Express Fes...
# 2     CLASSIC TOY TRAIN SET TRACK CARRIAGES LIGHT EN...
# 3        HORNBY Coach R4410A BR Hawksworth Corridor 3rd
# 4     Hornby 00 Gauge 0-4-0 Gildenlow Salt Co. Steam...
# ...                                                 ...
# 9995  Batman 1966 TV Series Action Figures - The Rid...
# 9996  Star Wars Costume, Kids Stormtrooper Costume S...
# 9997        Defiance Lawkeeper Metal Badge Prop Replica
# 9998  Justice League of America Series 3 Green Lante...
# 9999                  Star Wars 1/72 Y-Wing Starfighter
#
#                  manufacturer   price number_available_in_stock  \
# 0                      Hornby   £3.42                     5 new
# 1                   FunkyBuys  £16.99                       NaN
# 2                         ccf   £9.99                     2 new
# 3                      Hornby  £39.99                       NaN
# 4                      Hornby  £32.19                       NaN
# ...                       ...     ...                       ...
# 9995                   Mattel  £22.95                     5 new
# 9996                Star Wars  £39.99                       NaN
# 9997  Olde Scotland Yard Ltd.  £43.99                     3 new
# 9998                DC Comics  £49.81                     3 new
# 9999                   Bandai  £21.20                    31 new
#
#      number_of_reviews  number_of_answered_questions average_review_rating  \
# 0                   15                           1.0    4.9 out of 5 stars
# 1                    2                           1.0    4.5 out of 5 stars
# 2                   17                           2.0    3.9 out of 5 stars
# 3                    1                           2.0    5.0 out of 5 stars
# 4                    3                           2.0    4.7 out of 5 stars
# ...                ...                           ...                   ...
# 9995                 3                           3.0    5.0 out of 5 stars
# 9996                 1                           3.0    4.0 out of 5 stars
# 9997                 1                           3.0    5.0 out of 5 stars
# 9998                 1                           3.0    5.0 out of 5 stars
# 9999                11                           3.0    4.5 out of 5 stars
#
#                        amazon_category_and_sub_category  \
# 0     Hobbies > Model Trains & Railway Sets > Rail V...
# 1     Hobbies > Model Trains & Railway Sets > Rail V...
# 2     Hobbies > Model Trains & Railway Sets > Rail V...
# 3     Hobbies > Model Trains & Railway Sets > Rail V...
# 4     Hobbies > Model Trains & Railway Sets > Rail V...
# ...                                                 ...
# 9995  Hobbies > Collectible Figures & Memorabilia > ...
# 9996             Characters & Brands > Star Wars > Toys
# 9997  Novelty & Special Use > Novelty > Accessories ...
# 9998  Hobbies > Collectible Figures & Memorabilia > ...
# 9999             Characters & Brands > Star Wars > Toys
#
#              customers_who_bought_this_item_also_bought  \
# 0     http://www.amazon.co.uk/Hornby-R8150-Catalogue...
# 1     http://www.amazon.co.uk/Christmas-Holiday-Expr...
# 2     http://www.amazon.co.uk/Classic-Train-Lights-B...
# 3                                                   NaN
# 4     http://www.amazon.co.uk/Hornby-R6367-RailRoad-...
# ...                                                 ...
# 9995  http://www.amazon.co.uk/Batman-1966-Series-Act...
# 9996  http://www.amazon.co.uk/Storm-Trooper-Costume-...
# 9997                                                NaN
# 9998                                                NaN
# 9999  http://www.amazon.co.uk/Bandai-Star-Wars-Fight...
#
#                                             description  \
# 0     Product Description Hornby 2014 Catalogue Box ...
# 1     Size Name:Large FunkyBuys® Large Christmas Hol...
# 2     BIG CLASSIC TOY TRAIN SET TRACK CARRIAGE LIGHT...
# 3     Hornby 00 Gauge BR Hawksworth 3rd Class W 2107...
# 4     Product Description Hornby RailRoad 0-4-0 Gild...
# ...                                                 ...
# 9995  DC 66 Batman Classic TV Series 6 Inch Riddler ...
# 9996                                                NaN
# 9997  *Includes 1x Badge with holder and chain *High...
# 9998  Designed by Ed BenesIt's here - the third seri...
# 9999                                                NaN
#
#                                     product_information  \
# 0     Technical Details Item Weight640 g Product Dim...
# 1     Technical Details Manufacturer recommended age...
# 2     Technical Details Manufacturer recommended age...
# 3     Technical Details Item Weight259 g Product Dim...
# 4     Technical Details Item Weight159 g Product Dim...
# ...                                                 ...
# 9995  Technical Details Item Weight136 g Product Dim...
# 9996  Technical Details    Additional Information AS...
# 9997  Technical Details Item Weight159 g Product Dim...
# 9998  Technical Details Item Weight181 g Product Dim...
# 9999  Technical Details Item Weight299 g Product Dim...
#
#                                     product_description  \
# 0     Product Description Hornby 2014 Catalogue Box ...
# 1     Size Name:Large FunkyBuys® Large Christmas Hol...
# 2     BIG CLASSIC TOY TRAIN SET TRACK CARRIAGE LIGHT...
# 3     Hornby 00 Gauge BR Hawksworth 3rd Class W 2107...
# 4     Product Description Hornby RailRoad 0-4-0 Gild...
# ...                                                 ...
# 9995  DC 66 Batman Classic TV Series 6 Inch Riddler ...
# 9996                                                NaN
# 9997  *Includes 1x Badge with holder and chain *High...
# 9998  Designed by Ed BenesIt's here - the third seri...
# 9999                                                NaN
#
#             items_customers_buy_after_viewing_this_item  \
# 0     http://www.amazon.co.uk/Hornby-R8150-Catalogue...
# 1     http://www.amazon.co.uk/Christmas-Holiday-Expr...
# 2     http://www.amazon.co.uk/Train-With-Tracks-Batt...
# 3                                                   NaN
# 4     http://www.amazon.co.uk/Hornby-R2672-RailRoad-...
# ...                                                 ...
# 9995                                                NaN
# 9996  http://www.amazon.co.uk/Storm-Trooper-Costume-...
# 9997  http://www.amazon.co.uk/Olde-Scotland-Yard-Ltd...
# 9998                                                NaN
# 9999                                                NaN
#
#                          customer_questions_and_answers  \
# 0     Does this catalogue detail all the previous Ho...
# 1     can you turn off sounds // hi no you cant turn...
# 2     What is the gauge of the track // Hi Paul.Trut...
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 9995                                                NaN
# 9996                                                NaN
# 9997                                                NaN
# 9998                                                NaN
# 9999                                                NaN
#
#                                        customer_reviews  \
# 0     Worth Buying For The Pictures Alone (As Ever) ...
# 1     Four Stars // 4.0 // 18 Dec. 2015 // By\n    \...
# 2     **Highly Recommended!** // 5.0 // 26 May 2015 ...
# 3     I love it // 5.0 // 22 July 2013 // By\n    \n...
# 4     Birthday present // 5.0 // 14 April 2014 // By...
# ...                                                 ...
# 9995  Realistic // 5.0 // 31 Mar. 2014 // By\n    \n...
# 9996  ... what I see my grandson us going to have fu...
# 9997  Five Stars // 5.0 // 18 Dec. 2015 // By\n    \...
# 9998  The best sculpt in a while // 5.0 // 13 May 20...
# 9999  Gold leader // 5.0 // 31 Aug. 2015 // By\n    ...
#
#                                                 sellers
# 0     {"seller"=>[{"Seller_name_1"=>"Amazon.co.uk", ...
# 1     {"seller"=>{"Seller_name_1"=>"UHD WHOLESALE", ...
# 2     {"seller"=>[{"Seller_name_1"=>"DEAL-BOX", "Sel...
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 9995  {"seller"=>[{"Seller_name_1"=>"Star Action Fig...
# 9996                                                NaN
# 9997  {"seller"=>[{"Seller_name_1"=>"YUK", "Seller_p...
# 9998  {"seller"=>[{"Seller_name_1"=>"Smaller World F...
# 9999                                                NaN
#
# [10000 rows x 17 columns]

# %%
Data1 = Data.drop(columns = ["uniq_id","customers_who_bought_this_item_also_bought","description","product_information","product_description","items_customers_buy_after_viewing_this_item","customer_questions_and_answers","sellers","number_of_answered_questions","customer_reviews"])
Data1
# Out:
#                                            product_name  \
# 0                                 Hornby 2014 Catalogue
# 1     FunkyBuys® Large Christmas Holiday Express Fes...
# 2     CLASSIC TOY TRAIN SET TRACK CARRIAGES LIGHT EN...
# 3        HORNBY Coach R4410A BR Hawksworth Corridor 3rd
# 4     Hornby 00 Gauge 0-4-0 Gildenlow Salt Co. Steam...
# ...                                                 ...
# 9995  Batman 1966 TV Series Action Figures - The Rid...
# 9996  Star Wars Costume, Kids Stormtrooper Costume S...
# 9997        Defiance Lawkeeper Metal Badge Prop Replica
# 9998  Justice League of America Series 3 Green Lante...
# 9999                  Star Wars 1/72 Y-Wing Starfighter
#
#                  manufacturer   price number_available_in_stock  \
# 0                      Hornby   £3.42                     5 new
# 1                   FunkyBuys  £16.99                       NaN
# 2                         ccf   £9.99                     2 new
# 3                      Hornby  £39.99                       NaN
# 4                      Hornby  £32.19                       NaN
# ...                       ...     ...                       ...
# 9995                   Mattel  £22.95                     5 new
# 9996                Star Wars  £39.99                       NaN
# 9997  Olde Scotland Yard Ltd.  £43.99                     3 new
# 9998                DC Comics  £49.81                     3 new
# 9999                   Bandai  £21.20                    31 new
#
#      number_of_reviews average_review_rating  \
# 0                   15    4.9 out of 5 stars
# 1                    2    4.5 out of 5 stars
# 2                   17    3.9 out of 5 stars
# 3                    1    5.0 out of 5 stars
# 4                    3    4.7 out of 5 stars
# ...                ...                   ...
# 9995                 3    5.0 out of 5 stars
# 9996                 1    4.0 out of 5 stars
# 9997                 1    5.0 out of 5 stars
# 9998                 1    5.0 out of 5 stars
# 9999                11    4.5 out of 5 stars
#
#                        amazon_category_and_sub_category
# 0     Hobbies > Model Trains & Railway Sets > Rail V...
# 1     Hobbies > Model Trains & Railway Sets > Rail V...
# 2     Hobbies > Model Trains & Railway Sets > Rail V...
# 3     Hobbies > Model Trains & Railway Sets > Rail V...
# 4     Hobbies > Model Trains & Railway Sets > Rail V...
# ...                                                 ...
# 9995  Hobbies > Collectible Figures & Memorabilia > ...
# 9996             Characters & Brands > Star Wars > Toys
# 9997  Novelty & Special Use > Novelty > Accessories ...
# 9998  Hobbies > Collectible Figures & Memorabilia > ...
# 9999             Characters & Brands > Star Wars > Toys
#
# [10000 rows x 7 columns]

# %%
Data2 = Data1.rename(columns = {"product_name":"Product Name", "manufacturer":"Manufacturer","number_available_in_stock":"Available Stock","number_of_reviews":"Number of Reviews","average_review_rating":"Average Rating (Out of 5)", "price":"Price (£)", "amazon_category_and_sub_category": "Category"})
Data2["Price (£)"] = Data2["Price (£)"].str.replace("£","")
Data2["Average Rating (Out of 5)"] = Data2["Average Rating (Out of 5)"].str.replace(" out of 5 stars","")
Data2
# Out:
#                                            Product Name  \
# 0                                 Hornby 2014 Catalogue
# 1     FunkyBuys® Large Christmas Holiday Express Fes...
# 2     CLASSIC TOY TRAIN SET TRACK CARRIAGES LIGHT EN...
# 3        HORNBY Coach R4410A BR Hawksworth Corridor 3rd
# 4     Hornby 00 Gauge 0-4-0 Gildenlow Salt Co. Steam...
# ...                                                 ...
# 9995  Batman 1966 TV Series Action Figures - The Rid...
# 9996  Star Wars Costume, Kids Stormtrooper Costume S...
# 9997        Defiance Lawkeeper Metal Badge Prop Replica
# 9998  Justice League of America Series 3 Green Lante...
# 9999                  Star Wars 1/72 Y-Wing Starfighter
#
#                  Manufacturer Price (£) Available Stock Number of Reviews  \
# 0                      Hornby      3.42           5 new                15
# 1                   FunkyBuys     16.99             NaN                 2
# 2                         ccf      9.99           2 new                17
# 3                      Hornby     39.99             NaN                 1
# 4                      Hornby     32.19             NaN                 3
# ...                       ...       ...             ...               ...
# 9995                   Mattel     22.95           5 new                 3
# 9996                Star Wars     39.99             NaN                 1
# 9997  Olde Scotland Yard Ltd.     43.99           3 new                 1
# 9998                DC Comics     49.81           3 new                 1
# 9999                   Bandai     21.20          31 new                11
#
#      Average Rating (Out of 5)  \
# 0                          4.9
# 1                          4.5
# 2                          3.9
# 3                          5.0
# 4                          4.7
# ...                        ...
# 9995                       5.0
# 9996                       4.0
# 9997                       5.0
# 9998                       5.0
# 9999                       4.5
#
#                                                Category
# 0     Hobbies > Model Trains & Railway Sets > Rail V...
# 1     Hobbies > Model Trains & Railway Sets > Rail V...
# 2     Hobbies > Model Trains & Railway Sets > Rail V...
# 3     Hobbies > Model Trains & Railway Sets > Rail V...
# 4     Hobbies > Model Trains & Railway Sets > Rail V...
# ...                                                 ...
# 9995  Hobbies > Collectible Figures & Memorabilia > ...
# 9996             Characters & Brands > Star Wars > Toys
# 9997  Novelty & Special Use > Novelty > Accessories ...
# 9998  Hobbies > Collectible Figures & Memorabilia > ...
# 9999             Characters & Brands > Star Wars > Toys
#
# [10000 rows x 7 columns]

# %%
Data2["Available Stock"] = Data2["Available Stock"].str.replace("new","")

# Replacing NaNs with 0 for stocks and reviews
Data2["Available Stock"] = Data2["Available Stock"].fillna(0)
Data2["Number of Reviews"] = Data2["Number of Reviews"].fillna(0)
Data2
# Out:
#                                            Product Name  \
# 0                                 Hornby 2014 Catalogue
# 1     FunkyBuys® Large Christmas Holiday Express Fes...
# 2     CLASSIC TOY TRAIN SET TRACK CARRIAGES LIGHT EN...
# 3        HORNBY Coach R4410A BR Hawksworth Corridor 3rd
# 4     Hornby 00 Gauge 0-4-0 Gildenlow Salt Co. Steam...
# ...                                                 ...
# 9995  Batman 1966 TV Series Action Figures - The Rid...
# 9996  Star Wars Costume, Kids Stormtrooper Costume S...
# 9997        Defiance Lawkeeper Metal Badge Prop Replica
# 9998  Justice League of America Series 3 Green Lante...
# 9999                  Star Wars 1/72 Y-Wing Starfighter
#
#                  Manufacturer Price (£) Available Stock Number of Reviews  \
# 0                      Hornby      3.42              5                 15
# 1                   FunkyBuys     16.99               0                 2
# 2                         ccf      9.99              2                 17
# 3                      Hornby     39.99               0                 1
# 4                      Hornby     32.19               0                 3
# ...                       ...       ...             ...               ...
# 9995                   Mattel     22.95              5                  3
# 9996                Star Wars     39.99               0                 1
# 9997  Olde Scotland Yard Ltd.     43.99              3                  1
# 9998                DC Comics     49.81              3                  1
# 9999                   Bandai     21.20             31                 11
#
#      Average Rating (Out of 5)  \
# 0                          4.9
# 1                          4.5
# 2                          3.9
# 3                          5.0
# 4                          4.7
# ...                        ...
# 9995                       5.0
# 9996                       4.0
# 9997                       5.0
# 9998                       5.0
# 9999                       4.5
#
#                                                Category
# 0     Hobbies > Model Trains & Railway Sets > Rail V...
# 1     Hobbies > Model Trains & Railway Sets > Rail V...
# 2     Hobbies > Model Trains & Railway Sets > Rail V...
# 3     Hobbies > Model Trains & Railway Sets > Rail V...
# 4     Hobbies > Model Trains & Railway Sets > Rail V...
# ...                                                 ...
# 9995  Hobbies > Collectible Figures & Memorabilia > ...
# 9996             Characters & Brands > Star Wars > Toys
# 9997  Novelty & Special Use > Novelty > Accessories ...
# 9998  Hobbies > Collectible Figures & Memorabilia > ...
# 9999             Characters & Brands > Star Wars > Toys
#
# [10000 rows x 7 columns]

# %%
Data2["Available Stock"].isnull().sum()
Data2["Number of Reviews"].isnull().sum()
# Out:
# 0

# %%
Data2[["Category","Subcategory","Subcategory2","Subcategory3","Subcategory4"]] = Data2["Category"].str.split(">", expand = True)
Data2
# Out:
#                                            Product Name  \
# 0                                 Hornby 2014 Catalogue
# 1     FunkyBuys® Large Christmas Holiday Express Fes...
# 2     CLASSIC TOY TRAIN SET TRACK CARRIAGES LIGHT EN...
# 3        HORNBY Coach R4410A BR Hawksworth Corridor 3rd
# 4     Hornby 00 Gauge 0-4-0 Gildenlow Salt Co. Steam...
# ...                                                 ...
# 9995  Batman 1966 TV Series Action Figures - The Rid...
# 9996  Star Wars Costume, Kids Stormtrooper Costume S...
# 9997        Defiance Lawkeeper Metal Badge Prop Replica
# 9998  Justice League of America Series 3 Green Lante...
# 9999                  Star Wars 1/72 Y-Wing Starfighter
#
#                  Manufacturer Price (£) Available Stock Number of Reviews  \
# 0                      Hornby      3.42              5                 15
# 1                   FunkyBuys     16.99               0                 2
# 2                         ccf      9.99              2                 17
# 3                      Hornby     39.99               0                 1
# 4                      Hornby     32.19               0                 3
# ...                       ...       ...             ...               ...
# 9995                   Mattel     22.95              5                  3
# 9996                Star Wars     39.99               0                 1
# 9997  Olde Scotland Yard Ltd.     43.99              3                  1
# 9998                DC Comics     49.81              3                  1
# 9999                   Bandai     21.20             31                 11
#
#      Average Rating (Out of 5)                Category  \
# 0                          4.9                Hobbies
# 1                          4.5                Hobbies
# 2                          3.9                Hobbies
# 3                          5.0                Hobbies
# 4                          4.7                Hobbies
# ...                        ...                     ...
# 9995                       5.0                Hobbies
# 9996                       4.0    Characters & Brands
# 9997                       5.0  Novelty & Special Use
# 9998                       5.0                Hobbies
# 9999                       4.5    Characters & Brands
#
#                               Subcategory                      Subcategory2  \
# 0            Model Trains & Railway Sets                     Rail Vehicles
# 1            Model Trains & Railway Sets                     Rail Vehicles
# 2            Model Trains & Railway Sets                     Rail Vehicles
# 3            Model Trains & Railway Sets                     Rail Vehicles
# 4            Model Trains & Railway Sets                     Rail Vehicles
# ...                                   ...                               ...
# 9995   Collectible Figures & Memorabilia    Collectible Props & Memorabilia
# 9996                           Star Wars                               Toys
# 9997                             Novelty                       Accessories
# 9998   Collectible Figures & Memorabilia    Collectible Props & Memorabilia
# 9999                           Star Wars                               Toys
#
#          Subcategory3 Subcategory4
# 0              Trains         None
# 1              Trains         None
# 2              Trains         None
# 3              Trains         None
# 4              Trains         None
# ...               ...          ...
# 9995             None         None
# 9996             None         None
# 9997   Buttons & Pins         None
# 9998             None         None
# 9999             None         None
#
# [10000 rows x 11 columns]

# %%
Data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Product Name               10000 non-null  object
#  1   Manufacturer               9993 non-null   object
#  2   Price (£)                  8565 non-null   object
#  3   Available Stock            10000 non-null  object
#  4   Number of Reviews          10000 non-null  object
#  5   Average Rating (Out of 5)  9982 non-null   object
#  6   Category                   9310 non-null   object
#  7   Subcategory                9310 non-null   object
#  8   Subcategory2               5387 non-null   object
#  9   Subcategory3               1397 non-null   object
#  10  Subcategory4               85 non-null     object
# dtypes: object(11)
# memory usage: 859.5+ KB

# %% [markdown]
# We will drop Subcategory 2,3 and 4 as we are only interested in Category and Subcategory, In addition to this, most of them only contain category and subcategory information. We will also drop Null values from prices and ratings since we are only interested in products with actual prices and ratings

# %%
Data2 = Data2.drop(columns = ["Subcategory2","Subcategory3","Subcategory4"])
Data3 = Data2.dropna(subset = ["Price (£)","Average Rating (Out of 5)"])
Data3
# Out:
#                                            Product Name  \
# 0                                 Hornby 2014 Catalogue
# 1     FunkyBuys® Large Christmas Holiday Express Fes...
# 2     CLASSIC TOY TRAIN SET TRACK CARRIAGES LIGHT EN...
# 3        HORNBY Coach R4410A BR Hawksworth Corridor 3rd
# 4     Hornby 00 Gauge 0-4-0 Gildenlow Salt Co. Steam...
# ...                                                 ...
# 9995  Batman 1966 TV Series Action Figures - The Rid...
# 9996  Star Wars Costume, Kids Stormtrooper Costume S...
# 9997        Defiance Lawkeeper Metal Badge Prop Replica
# 9998  Justice League of America Series 3 Green Lante...
# 9999                  Star Wars 1/72 Y-Wing Starfighter
#
#                  Manufacturer Price (£) Available Stock Number of Reviews  \
# 0                      Hornby      3.42              5                 15
# 1                   FunkyBuys     16.99               0                 2
# 2                         ccf      9.99              2                 17
# 3                      Hornby     39.99               0                 1
# 4                      Hornby     32.19               0                 3
# ...                       ...       ...             ...               ...
# 9995                   Mattel     22.95              5                  3
# 9996                Star Wars     39.99               0                 1
# 9997  Olde Scotland Yard Ltd.     43.99              3                  1
# 9998                DC Comics     49.81              3                  1
# 9999                   Bandai     21.20             31                 11
#
#      Average Rating (Out of 5)                Category  \
# 0                          4.9                Hobbies
# 1                          4.5                Hobbies
# 2                          3.9                Hobbies
# 3                          5.0                Hobbies
# 4                          4.7                Hobbies
# ...                        ...                     ...
# 9995                       5.0                Hobbies
# 9996                       4.0    Characters & Brands
# 9997                       5.0  Novelty & Special Use
# 9998                       5.0                Hobbies
# 9999                       4.5    Characters & Brands
#
#                               Subcategory
# 0            Model Trains & Railway Sets
# 1            Model Trains & Railway Sets
# 2            Model Trains & Railway Sets
# 3            Model Trains & Railway Sets
# 4            Model Trains & Railway Sets
# ...                                   ...
# 9995   Collectible Figures & Memorabilia
# 9996                           Star Wars
# 9997                             Novelty
# 9998   Collectible Figures & Memorabilia
# 9999                           Star Wars
#
# [8550 rows x 8 columns]

# %%
#Reset index due to the drop of rows with NaNs
Data3.reset_index(drop=True, inplace = True)
Data3
# Out:
#                                            Product Name  \
# 0                                 Hornby 2014 Catalogue
# 1     FunkyBuys® Large Christmas Holiday Express Fes...
# 2     CLASSIC TOY TRAIN SET TRACK CARRIAGES LIGHT EN...
# 3        HORNBY Coach R4410A BR Hawksworth Corridor 3rd
# 4     Hornby 00 Gauge 0-4-0 Gildenlow Salt Co. Steam...
# ...                                                 ...
# 8545  Batman 1966 TV Series Action Figures - The Rid...
# 8546  Star Wars Costume, Kids Stormtrooper Costume S...
# 8547        Defiance Lawkeeper Metal Badge Prop Replica
# 8548  Justice League of America Series 3 Green Lante...
# 8549                  Star Wars 1/72 Y-Wing Starfighter
#
#                  Manufacturer Price (£) Available Stock Number of Reviews  \
# 0                      Hornby      3.42              5                 15
# 1                   FunkyBuys     16.99               0                 2
# 2                         ccf      9.99              2                 17
# 3                      Hornby     39.99               0                 1
# 4                      Hornby     32.19               0                 3
# ...                       ...       ...             ...               ...
# 8545                   Mattel     22.95              5                  3
# 8546                Star Wars     39.99               0                 1
# 8547  Olde Scotland Yard Ltd.     43.99              3                  1
# 8548                DC Comics     49.81              3                  1
# 8549                   Bandai     21.20             31                 11
#
#      Average Rating (Out of 5)                Category  \
# 0                          4.9                Hobbies
# 1                          4.5                Hobbies
# 2                          3.9                Hobbies
# 3                          5.0                Hobbies
# 4                          4.7                Hobbies
# ...                        ...                     ...
# 8545                       5.0                Hobbies
# 8546                       4.0    Characters & Brands
# 8547                       5.0  Novelty & Special Use
# 8548                       5.0                Hobbies
# 8549                       4.5    Characters & Brands
#
#                               Subcategory
# 0            Model Trains & Railway Sets
# 1            Model Trains & Railway Sets
# 2            Model Trains & Railway Sets
# 3            Model Trains & Railway Sets
# 4            Model Trains & Railway Sets
# ...                                   ...
# 8545   Collectible Figures & Memorabilia
# 8546                           Star Wars
# 8547                             Novelty
# 8548   Collectible Figures & Memorabilia
# 8549                           Star Wars
#
# [8550 rows x 8 columns]

# %%
#Confirming NaN dropped from prices and ratings(by finding the sum of NaNs)

Data3[["Price (£)","Average Rating (Out of 5)"]].isna().sum()
# Out:
# Price (£)                    0
# Average Rating (Out of 5)    0
# dtype: int64

# %%
Data3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8550 entries, 0 to 8549
# Data columns (total 8 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Product Name               8550 non-null   object
#  1   Manufacturer               8545 non-null   object
#  2   Price (£)                  8550 non-null   object
#  3   Available Stock            8550 non-null   object
#  4   Number of Reviews          8550 non-null   object
#  5   Average Rating (Out of 5)  8550 non-null   object
#  6   Category                   8003 non-null   object
#  7   Subcategory                8003 non-null   object
# dtypes: object(8)
# memory usage: 534.5+ KB

# %%
# found out ranges of prices in the price column
# I will take the minimum by expanding using delimiter and then dropping max price]

# Also found out incorrectly listed prices that contain commas. 
# My choice is to remove them and see if it will have any impact on the data

# Also, I will remove non-numeric characters from the Available Stock and Number of Reviews and fill NaNs again with zero incase they arise

Data3[["Price (£)", "Max Price"]] = Data3["Price (£)"].str.split("-", expand = True)
Data3.drop(columns = ["Max Price"])

Data3 = Data3[~Data3["Price (£)"].str.contains(',')]
Data3.info()

Data3["Available Stock"] = Data3["Available Stock"].str.replace(r'\D', '')
Data3["Number of Reviews"] = Data3["Number of Reviews"].str.replace(r'\D', '')
Data3["Available Stock"].fillna(0, inplace=True)
Data3["Number of Reviews"].fillna(0, inplace=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8549 entries, 0 to 8549
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Product Name               8549 non-null   object
#  1   Manufacturer               8544 non-null   object
#  2   Price (£)                  8549 non-null   object
#  3   Available Stock            8549 non-null   object
#  4   Number of Reviews          8549 non-null   object
#  5   Average Rating (Out of 5)  8549 non-null   object
#  6   Category                   8002 non-null   object
#  7   Subcategory                8002 non-null   object
#  8   Max Price                  18 non-null     object
# dtypes: object(9)
# memory usage: 667.9+ KB
# C:\Users\omarm\AppData\Local\Temp\ipykernel_54224\4177934317.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Data3[["Price (£)", "Max Price"]] = Data3["Price (£)"].str.split("-", expand = True)
# C:\Users\omarm\AppData\Local\Temp\ipykernel_54224\4177934317.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Data3[["Price (£)", "Max Price"]] = Data3["Price (£)"].str.split("-", expand = True)
# C:\Users\omarm\AppData\Local\Temp\ipykernel_54224\4177934317.py:15: FutureWarning: The default value of regex will change from True to False in a future version.
#   Data3["Available Stock"] = Data3["Available Stock"].str.replace(r'\D', '')
# C:\Users\omarm\AppData\Local\Temp\ipykernel_54224\4177934317.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Data3["Available Stock"] = Data3["Available Stock"].str.replace(r'\D', '')
# C:\Users\omarm\AppData\Local\Temp\ipykernel_54224\4177934317.py:16: FutureWarning: The default value of regex will change from True to False in a future version.
#   Data3["Number of Reviews"] = Data3["Number of Reviews"].str.replace(r'\D', '')
# C:\Users\omarm\AppData\Local\Temp\ipykernel_54224\4177934317.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Data3["Number of Reviews"] = Data3["Number of Reviews"].str.replace(r'\D', '')
# C:\Users\omarm\AppData\Local\Temp\ipykernel_54224\4177934317.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Data3["Available Stock"].fillna(0, inplace=True)
# C:\Users\omarm\AppData\Local\Temp\ipykernel_54224\4177934317.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Data3["Number of Reviews"].fillna(0, inplace=True)

# %%
# Here, I convert data types to make it easy to work with the different data types
Data3["Price (£)"] = Data3["Price (£)"].astype('float')
Data3["Average Rating (Out of 5)"] = Data3["Average Rating (Out of 5)"].astype('float')
Data3["Available Stock"] = Data3["Available Stock"].astype('int')
Data3["Number of Reviews"] = Data3["Number of Reviews"].astype('int')

Data3.dtypes
# Out:
# C:\Users\omarm\AppData\Local\Temp\ipykernel_54224\1993497848.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Data3["Price (£)"] = Data3["Price (£)"].astype('float')
# C:\Users\omarm\AppData\Local\Temp\ipykernel_54224\1993497848.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Data3["Average Rating (Out of 5)"] = Data3["Average Rating (Out of 5)"].astype('float')
# C:\Users\omarm\AppData\Local\Temp\ipykernel_54224\1993497848.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Data3["Available Stock"] = Data3["Available Stock"].astype('int')
# C:\Users\omarm\AppData\Local\Temp\ipykernel_54224\1993497848.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Data3["Number of Reviews"] = Data3["Number of Reviews"].astype('int')
# Product Name                  object
# Manufacturer                  object
# Price (£)                    float64
# Available Stock                int32
# Number of Reviews              int32
# Average Rating (Out of 5)    float64
# Category                      object
# Subcategory                   object
# Max Price                     object
# dtype: object

# %% [markdown]
# Data is ready for use! I converted the NaNs in Number of Reviews and Available Stock to zero because I believe we can use them to find interesting information from the data such as how products with NaN in available stock (i.e zero stock) vary with the customer rating etc!
#
# An interesting hypothesis to test, in the case that NaN is replaced with 0, could be that products with NaNs (zero) in stock are likely to be products with high customer rating because it could signifiy that they are products loved by customers and thus are sold out.
#
# I will export the cleaned data to Tableau as a CSV file ready for creating a Dashboard that will answer a few business questions!

# %%
Cleaned = Data3.to_csv(r"C:\Users\omarm\Documents\Career Essentials & Job Apps\Guided Projects with Business Problems-or-Requirements\Amazon.csv", index = False)
